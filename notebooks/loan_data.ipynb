# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from urllib import request

# %%
url = "https://www.nbp.pl/systemfinansowy/zrodlo-roz.xlsx"

# %% [markdown]
# Download data

# %%
path = '../data/loans.xlsx'
# Download remote and save locally
data = request.urlretrieve(url, path)

# %% [markdown]
# Read data into dataframe

# %%
df = pd.read_excel(path,sheet_name=0)

# %%
df
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN  Kwartał, którego dotyczą pytania o przewidywan...     I.2004
# 1           NaN        Kwartał, którego dotyczą pytania o stan (S)    IV.2003
# 2           NaN                                                NaN        NaN
# 3           NaN                            Sektor przedsiębiorstw:        NaN
# 4           NaN                                                NaN        NaN
# ..          ...                                                ...        ...
# 127         NaN                               Kredyty konsumpcyjne   0.297676
# 128         NaN                                                NaN        NaN
# 129         NaN                       Pyt. 17: Popyt na kredyt (P)        NaN
# 130         NaN                               Kredyty mieszkaniowe      0.332
# 131         NaN                               Kredyty konsumpcyjne   0.364543
#
# ...

# %%
#pick row nr 3 as columns names
cols = df.iloc[1:2, 1:110].values
#slice the dataframe
df = df.iloc[108:115, 1:79]
#and change its column names
df.columns = cols[0]
df.rename(columns={'Kwartał, którego dotyczą pytania o stan (S)':'parameters'})
# Out:
#                                             parameters   IV.2003    I.2004  \
# 108  Prognozy odnośnie sytuacji na rynku mieszkaniowym  0.431139  0.591632
# 109                  Zmiany w wydatkach konsumpcyjnych  -0.04644  0.073255
# 110   Wykorzystanie alternatywnych źródeł finansowania -0.046538  0.032498
# 111  Zmiana sytuacji ekonomicznej gospodarstw domowych   0.03626  0.304602
# 112  Zmiana warunków udzielania kredytów mieszkanio...   0.28006  0.339085
# 113  Zmiana kryteriów udzielania kredytów mieszkani...  0.236574 -0.150207
# 114                                      Inne czynniki -0.036145  0.092446
#
#       II.2004  III.2004   IV.2004    I.2005   II.2005  III.2005   IV.2005  \
# 108  0.809363  0.230082  0.266053  0.482618  0.649565  0.418226  0.044749
# 109  0.083417 -0.038803    0.0079  0.393063  0.190305  0.202078         0
# 110  0.057612  0.027648  0.013183  -0.22202  0.465328  0.190659  0.035151
# ...

# %% [markdown]
# Lets transpose the table so the dates are in rows

# %%
df = df.transpose()
df
# Out:
#                                                                                            108  \
# Kwartał, którego dotyczą pytania o stan (S)  Prognozy odnośnie sytuacji na rynku mieszkaniowym
# IV.2003                                                                               0.431139
# I.2004                                                                                0.591632
# II.2004                                                                               0.809363
# III.2004                                                                              0.230082
# ...                                                                                        ...
# IV.2021                                                                              -0.157503
# I.2022                                                                               -0.282905
# II.2022                                                                              -0.473571
# ...

# %% [markdown]
# Rename firts fow with columns name

# %%
df.columns = df.iloc[0]

# %% [markdown]
# Remove first row

# %%
df = df[1:]

# %%
df
# Out:
# Kwartał, którego dotyczą pytania o stan (S) Prognozy odnośnie sytuacji na rynku mieszkaniowym  \
# IV.2003                                                                              0.431139
# I.2004                                                                               0.591632
# II.2004                                                                              0.809363
# III.2004                                                                             0.230082
# IV.2004                                                                              0.266053
# ...                                                                                       ...
# IV.2021                                                                             -0.157503
# I.2022                                                                              -0.282905
# II.2022                                                                             -0.473571
# ...

# %% [markdown]
# Lets work with data type in columns

# %%
#reset index, quarter will be new column
df = df.reset_index()
df.columns = ['Quarter', 'Loan_forcast', 'Changes_expenses', 'Alt_finansing', 'Change_economy', 'Change_rules', 'Change_criteria', 'Others']

#change type of all the columns with float type
cols = df.columns
df[cols[1:]] = df[cols[1:]].astype(float)

# %%
#change date columns to datetime
dates = df['Quarter'].to_list()
new_dates = []
for date in dates:
    q,y = date.split('.')
    if q == 'I': q = 'Q1'
    if q == 'II': q = 'Q2'
    if q == 'III': q = 'Q3'
    if q == 'IV': q = 'Q4'
    new_dates.append(y + '-' + q)
new_dates

#update dates and change data type
df['Quarter'] = new_dates
df['Date'] = pd.to_datetime(df['Quarter'])

#delate Quarter column
df = df.drop('Quarter', axis=1)

df.dtypes
# Out:
# Loan_forcast               float64
# Changes_expenses           float64
# Alt_finansing              float64
# Change_economy             float64
# Change_rules               float64
# Change_criteria            float64
# Others                     float64
# Date                datetime64[ns]
# dtype: object

# %%
# %store df
df
# Out:
# Stored 'df' (DataFrame)
#     Loan_forcast  Changes_expenses  Alt_finansing  Change_economy  \
# 0       0.431139         -0.046440      -0.046538        0.036260
# 1       0.591632          0.073255       0.032498        0.304602
# 2       0.809363          0.083417       0.057612        0.149892
# 3       0.230082         -0.038803       0.027648        0.224047
# 4       0.266053          0.007900       0.013183        0.217630
# ..           ...               ...            ...             ...
# 72     -0.157503         -0.145476      -0.035757       -0.144237
# 73     -0.282905         -0.466923      -0.075526       -0.495623
# 74     -0.473571         -0.508385      -0.133011       -0.564630
# 75     -0.549571         -0.440012      -0.119988       -0.638404
# 76     -0.079312         -0.344548      -0.092880       -0.476696
#
#     Change_rules  Change_criteria    Others       Date
# 0       0.280060         0.236574 -0.036145 2003-10-01
# ...

# %% [markdown]
# One plot for better understending of data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(df, x='Date', y='Forcast')
sns.lineplot(df, x='Date', y='Changes_expenses')
sns.lineplot(df, x='Date', y='Change_criteria')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.lineplot(df, x='Date', y='Forcast')
#       4 sns.lineplot(df, x='Date', y='Changes_expenses')
#       5 sns.lineplot(df, x='Date', y='Change_criteria')
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
# ...

# %%
df.describe()
# Out:
#          Forcast  Changes_expenses  Alt_finansing  Change_economy  \
# count  77.000000         77.000000      77.000000       77.000000
# mean    0.075847         -0.019216      -0.020404       -0.014088
# std     0.270920          0.132003       0.084971        0.204330
# min    -0.684408         -0.508385      -0.222020       -0.638404
# 25%    -0.051074         -0.042853      -0.050724       -0.092097
# 50%     0.051655          0.000000      -0.013643        0.005906
# 75%     0.190870          0.005301       0.010447        0.062878
# max     0.809363          0.393063       0.465328        0.437900
#
#        Change_rules  Change_criteria     Others
# count     77.000000        77.000000  77.000000
# mean       0.002265        -0.037427   0.017414
# std        0.189201         0.159317   0.169385
# min       -0.700183        -0.635448  -0.567222
# 25%       -0.091528        -0.059210  -0.025768
# 50%        0.000000        -0.004998   0.027534
# ...

# %%
df.isnull().sum()
# Out:
# Forcast             0
# Changes_expenses    0
# Alt_finansing       0
# Change_economy      0
# Change_rules        0
# Change_criteria     0
# Others              0
# Date                0
# dtype: int64
